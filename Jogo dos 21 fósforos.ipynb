# %% [markdown]
# Jogo dos 21 fósforos

# %%
import random

def Computador_primeiro (comp_a, jogador_a):
    sum = comp_a + jogador_a
    if (sum==5 or sum==0):
        comp2=random.randint(1,4)
    elif (sum > 5):
        comp2 = 10 - sum
    elif (sum<5 and sum!=0):
        comp2=5-sum
    return comp2

def Computador_segundo (jogador_a):
    comp1=5-jogador_a
    return comp1

print("Bem-vindo ao Jogo dos 21 fósforos!")
print("Quer ser o primeiro(1) ou o segundo(2) a jogar?")

numero_fosf=21
numero_jog=1
jogador_anterior=0
computador_anterior=0

jogada=int(input())
if (jogada !=1 and jogada!=2):
    print("Erro!")
    print("Quer ser o primeiro(1) ou o segundo(2) a jogar?")
    jogada=int(input())
    
if (jogada==1):
    while (numero_fosf>0):
        a=numero_jog%2
        if (a!=0):
            print ("É a sua vez!")
            print("Quantos fósforos pretende retirar? (1 a 4 inclusive)")
            jogador=int(input())
            if (jogador != 1 and jogador !=2 and jogador!=3 and jogador!=4):
                print("Erro!")
                print("Quantos fósforos pretende retirar?")
                jogador=int(input())
            numero_fosf=numero_fosf-jogador
            jogador_anterior = jogador
        else:
            print("Jogada do Computador:")
            cpu = Computador_segundo(jogador_anterior)
            print(cpu)
            numero_fosf = numero_fosf - cpu
        numero_jog=numero_jog+1
    b=numero_jog%2
    if(b==0):
        print("Parabéns! Ganhou!")
    else:
        print("O Computador venceu!")
else:
    while (numero_fosf>0):
        a=numero_jog%2
        if(a==0):
            print("É a sua vez!")
            print("Quantos fósforos pretende retirar? (1 a 4 inclusive)")
            jogador= int=(input())
            if (jogador!=1 and jogador!=2 and jogador!=3 and jogador!=4):
                print("Erro!")
                print("Quantos fósforos pretende retirar?")
                jogador=int(input())
            numero_fosf=numero_fosf-jogador
            jogador_anterior=jogador
        else:
            print("Jogada do Computador")
            cpu= Computador_primeiro(computador_anterior, jogador_anterior)
            print(cpu)
            numero_fosf=numero_fosf - cpu
            computador_anterior=cpu
        numero_jog= numero_jog+1
    b = numero_jog %2
    if (b == 0):
        print("Parabéns, ganhou!")
    else:
        print("Perdeu!")
